# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.8.0.74-cp37-abi3-win_amd64.whl (38.1 MB)
# ...

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# alabaster                     0.7.12
# anaconda-client               1.11.2
# anaconda-navigator            2.4.0
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# atomicwrites                  1.4.0
# attrs                         22.1.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.11.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
Image(filename='download.png')

# %%
#Read image as grey scale
gs_img=cv2.imread('download.png',0)

# %%
#print te image data(pixel value)
print(gs_img)
# Out:
# [[ 10  10  10 ... 255 255 255]
#  [ 10  10  10 ... 255 255 255]
#  [ 10  10  10 ... 255 255 255]
#  ...
#  [255 255 255 ...  10  10  10]
#  [255 255 255 ...  10  10  10]
#  [255 255 255 ...  10  10  10]]

# %%
#print the size of image
print('image size=',gs_img.shape)

#print datatype of image
print('datatype=',gs_img.dtype)
# Out:
# image size= (166, 166)
# datatype= uint8

# %%
#display image using matplotlib
plt.imshow(gs_img)

# %%
#set the color map to grey scale for proper rendering
plt.imshow(gs_img,cmap='gray')
